# %% [markdown]
# <a href="https://colab.research.google.com/github/kvmkrao/cdml/blob/master/Object_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q PyYAML==5.3.1
# !pip install -qr https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt  # install dependencies
# Out:
#      |████████████████████████████████| 269 kB 5.5 MB/s
# ...

# %%
import torch

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)

# Images
#imgs = ['https://ultralytics.com/images/zidane.jpg']  # batch of images
imgs = ['https://storage.openvinotoolkit.org/data/test_data/images/224x224/dog.bmp']

# Inference
results = model(imgs)

# Results
results.show()
results.save()  # or .show() # print() or .show(), .save(), .crop(), .pandas(), etc.

results.xyxy[0]  # img1 predictions (tensor)
results.pandas().xyxy[0]  # img1 predictions (pandas)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to /root/.cache/torch/hub/master.zip
# requirements: PyYAML>=5.3.1 not found and is required by YOLOv5, attempting auto-update...
# ...
#
# requirements: 1 package updated per /root/.cache/torch/hub/ultralytics_yolov5_master/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 2022-5-4 torch 1.11.0+cu113 CPU
#
# ...
#   0%|          | 0.00/14.1M [00:00<?, ?B/s]
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...
# Saved 1 image to runs/detect/exp
#          xmin       ymin        xmax        ymax  confidence  class     name
# 0  110.560020  43.219345  149.376266   65.224365    0.582717     29  frisbee
# 1   47.953354  21.728935  151.150665  207.229050    0.479510     16      dog
